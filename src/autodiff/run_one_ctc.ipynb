# %% [markdown]
# ## Import Libs

# %%
import os,sys
# deepspeech path
current_directory = os.path.dirname('/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/')  # If running from a script
sys.path.append(current_directory)
os.environ["CUDA_VISIBLE_DEVICES"] = "6"

import torch
import torch.nn as nn
import hydra


from hydra.core.config_store import ConfigStore
from deepspeech_pytorch.configs.inference_config import EvalConfig
from deepspeech_pytorch.loader.data_loader import SpectrogramDataset, AudioDataLoader
from deepspeech_pytorch.utils import load_model, load_decoder
from deepspeech_pytorch.validation import run_evaluation
from deepspeech_pytorch.model import DeepSpeech, SequenceWise

from utils import *

from ctc_loss_imp import ctc_loss_imp
import matplotlib
# %matplotlib inline

# %%
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc1 = nn.Linear(161,1024)
        self.fc2 = nn.Linear(1024, 29)
        self.seq = SequenceWise(nn.Sequential(self.fc1, nn.Sigmoid(), self.fc2))
    def forward(self,x):
        #torch.Size([1, 1, 161, 20])
        n,c,h,t = x.shape
        x = x.permute(3,0,1,2) # tnch
        x = x.reshape(t,n, c*h)
        x = self.seq(x) # t,n,-1
        x = x.permute(1,0,2) # n,-1,t

        return x
model_simple = SimpleModel().cuda()

# %%
# ------------------------------------------------------------------------------
# Config 
# ------------------------------------------------------------------------------
cs = ConfigStore.instance()
cs.store(name="config", node=EvalConfig)

cfg = EvalConfig()

# set bs = 1, device
cfg.batch_size=1
device = torch.device("cuda" if cfg.model.cuda else "cpu")


# ------------------------------------------------------------------------------
# Model
# ------------------------------------------------------------------------------
model_path='/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/librispeech_pretrained_v3.ckpt'
model_path='/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/outputs/2023-11-01/23-31-50/lightning_logs/version_0/checkpoints/epoch=5-step=19295.ckpt'
model_ds = DeepSpeech.load_from_checkpoint(model_path)
model_ds.train()
model_ds = model_ds.to(device)

# ------------------------------------------------------------------------------
# Data
# ------------------------------------------------------------------------------

test_dir = '/scratch/f006pq6/datasets/librispeech/test_clean'
test_dataset = SpectrogramDataset(
    audio_conf=model_ds.spect_cfg,
    input_path=hydra.utils.to_absolute_path(test_dir),
    labels=model_ds.labels,
    normalize=True
)
test_loader = AudioDataLoader(
    test_dataset,
    batch_size=cfg.batch_size,
    num_workers=cfg.num_workers
)
# ------------------------------------------------------------------------------
# Get an Input
# ------------------------------------------------------------------------------


inputs, targets, input_percentages, target_sizes = next(iter(test_loader)) 
inputs = inputs.to(device)


# # ==============================================================================
# # Make the input a bit smaller

inputs = inputs[:,:,:,-60:-40] # do 100 frames only
input_percentages[0] = 1.0
input_sizes = input_percentages.mul_(int(inputs.size(3))).int()
input_percentages = input_percentages.to(device)

print(inputs.shape)
# Out:
# torch.Size([1, 1, 161, 20])

# %%
plot_spectrogram(inputs.detach())

# %%
# ------------------------------------------------------------------------------
#  Loss function, get target dL/dW
# ------------------------------------------------------------------------------
##get the param to match gradient
# weight_param = model_ds.fc[0].module[1].weight
weight_param = model_simple.fc2.weight

# out, output_sizes, hs = model_ds(inputs, input_sizes) # 1 176 29
out = model_simple(inputs) # 1 176 29

# ==============================================================================
# make target same length with inputs to use cross entr loss
targets = torch.randint(low=1, high=28, size = (1,out.shape[1])) .to(device)
target_sizes = torch.tensor([targets.shape[1]]).to(device)


# ==============================================================================
# if ctc
out = out.transpose(0, 1)  # TxNxH
out = out.log_softmax(-1) # if model in train, use log_softmax. else use log
# from torch.nn import CTCLoss
# loss_ = CTCLoss(blank=model_ds.labels.index('_'), reduction='sum', zero_infinity=True)(out, targets, output_sizes, target_sizes)


# ==============================================================================
# make output sizes equal output of network
# make random target size equal size of output
output_sizes = torch.tensor([out.shape[0]])
loss_func = lambda x,y :ctc_loss_imp(x, y, output_sizes, target_sizes,reduction='sum')

# ==============================================================================
# if crossentropy
# out = out.squeeze()
# targets = targets.squeeze()

# loss_func   = torch.nn.CrossEntropyLoss()
# ==============================================================================

loss = loss_func(out, targets)
# print(loss.item(), loss_.item())
# grab gradient to match
dldw_target= torch.autograd.grad(loss, weight_param)[0]

print('grad shape:',dldw_target.shape, 'grad_norm', dldw_target.norm())
# Out:
# grad shape: torch.Size([29, 1024]) grad_norm tensor(82.9071, device='cuda:0')

# %%
# ------------------------------------------------------------------------------
# Meta loss
# ------------------------------------------------------------------------------
def meta_loss(output, targets, output_sizes, target_sizes, dldw_target,  weight_param):
    loss = loss_func(output, targets)
    dldw = torch.autograd.grad(loss, weight_param, create_graph=True)[0]
    mse_loss = ((dldw-dldw_target)**2).sum()
    return mse_loss,dldw

# ------------------------------------------------------------------------------
# Init random input
# ------------------------------------------------------------------------------

x_hat = torch.nn.Parameter(torch.rand_like(inputs).to(device),requires_grad=True)

# %%
# ------------------------------------------------------------------------------
# Train
# ------------------------------------------------------------------------------
import torch.optim as optim

optimizer = optim.Adam([x_hat], lr=1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min',factor=.5,patience=100)

i=0
loss_history = []
while True:

    output = model_simple(x_hat) # 1 176 29
    # output, output_sizes, _= model_ds(x_hat, input_sizes) # 1 176 29
    # ==============================================================================
    # if crossentropy
    # output = output.squeeze()

    # ==============================================================================
    # if ctc
    output = output.transpose(0, 1)  # TxNxH
    output = output.log_softmax(-1) # if in training mode
    # output = output.log() # if in eval mode (deepspeech model already output softmax)

    # mloss, dldw_f = meta_loss(output, targets, output_sizes, target_sizes, dldw_target,  weight_param)
    mloss, dldw_f = meta_loss(output, targets, None, None, dldw_target,  weight_param)

    # add L2 regularization
    # mloss += .001 * torch.sum(x_hat**2) 
    optimizer.zero_grad()
    mloss.backward()
    grad = x_hat.grad.data

    optimizer.step()

    loss_history.append(mloss.item())

    if i % 10 == 0:
        print('Iteration, Loss, Gradient Norm, Learning Rate: {:4d}, {:.4f}, {:.4f}, {:.4f}'.format(i, mloss.item(), grad.norm().item(), optimizer.param_groups[0]["lr"]))
        scheduler.step(mloss.item())

    if (i+ 1) % 10000 == 0:
        torch.save({
            'model':model_ds.state_dict(),
            'loss_history': loss_history,
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
             }, f'model_checkpoint_{i+ 1}.pt')
        print(f'Model saved at iteration {i+ 1}')


    i+=1
# Out:
# Iteration, Loss, Gradient Norm, Learning Rate:    0, 0.5474, 0.8024, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   10, 160.3183, 13.6131, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   20, 53.7168, 7.0710, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   30, 13.8147, 2.6848, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   40, 6.8473, 1.9581, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   50, 3.0549, 1.2388, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   60, 1.3590, 0.7050, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   70, 0.7320, 0.4501, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   80, 0.4642, 0.3045, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:   90, 0.3223, 0.1606, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  100, 0.2630, 0.1081, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  110, 0.2272, 0.0608, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  120, 0.2063, 0.0391, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  130, 0.1922, 0.0245, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  140, 0.1821, 0.0161, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  150, 0.1746, 0.0110, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  160, 0.1688, 0.0081, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  170, 0.1643, 0.0064, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  180, 0.1607, 0.0054, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  190, 0.1578, 0.0046, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  200, 0.1555, 0.0041, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  210, 0.1535, 0.0037, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  220, 0.1520, 0.0033, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  230, 0.1507, 0.0030, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  240, 0.1496, 0.0027, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  250, 0.1487, 0.0025, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  260, 0.1479, 0.0022, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  270, 0.1473, 0.0021, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  280, 0.1467, 0.0019, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  290, 0.1463, 0.0017, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  300, 0.1459, 0.0016, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  310, 0.1455, 0.0015, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  320, 0.1452, 0.0014, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  330, 0.1449, 0.0013, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  340, 0.1447, 0.0013, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  350, 0.1449, 0.0218, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  360, 0.1540, 0.1059, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  370, 0.1448, 0.0275, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  380, 0.1444, 0.0192, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  390, 0.1481, 0.0567, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  400, 0.1452, 0.0349, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  410, 0.1448, 0.0356, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  420, 0.1477, 0.0689, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  430, 0.1454, 0.0472, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  440, 0.1442, 0.0277, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  450, 0.1438, 0.0202, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  460, 0.1455, 0.0396, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  470, 0.1449, 0.0389, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  480, 0.1500, 0.0893, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  490, 0.1461, 0.0584, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  500, 0.1466, 0.0643, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  510, 0.1437, 0.0245, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  520, 0.1438, 0.0271, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  530, 0.1493, 0.0690, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  540, 0.1600, 0.1387, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  550, 0.1790, 0.2105, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  560, 0.1497, 0.0976, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  570, 0.1474, 0.0735, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  580, 0.1471, 0.0721, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  590, 0.1481, 0.0904, 1.0000
# Iteration, Loss, Gradient Norm, Learning Rate:  600, 0.1498, 0.0999, 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> output = output.log_softmax(-1) # if in training mode
#      <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> # output = output.log() # if in eval mode (deepspeech model already output softmax)
#      <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>
#      <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> # mloss, dldw_f = meta_loss(output, targets, output_sizes, target_sizes, dldw_target,  weight_param)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> mloss, dldw_f = meta_loss(output, targets, None, None, dldw_target,  weight_param)
#      <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> # add L2 regularization
#      <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> # mloss += .001 * torch.sum(x_hat**2)
#      <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> optimizer.zero_grad()
#
# /scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb Cell 8 line 6
#       <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> def meta_loss(output, targets, output_sizes, target_sizes, dldw_target,  weight_param):
#       <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     loss = loss_func(output, targets)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     dldw = torch.autograd.grad(loss, weight_param, create_graph=True)[0]
#       <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     mse_loss = ((dldw-dldw_target)**2).sum()
#       <a href='vscode-notebook-cell://ssh-remote%2Blisplab1.thayer/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/notebooks/run_one_ctc.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     return mse_loss,dldw
#
# File /scratch/f006pq6/bin/miniconda3/envs/asr_reveal/lib/python3.9/site-packages/torch/autograd/__init__.py:300, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     298     return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     299 else:
# --> 300     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     301         t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     302         allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plot sth

# %%
# %matplotlib inline

# %%
plot_loss_over_epoch(loss_history, 'meta loss','epoch/10','meta loss')

# %%
plot_spectrogram(inputs.detach())

# %%
plot_spectrogram(x_hat.detach())

# %%
#pytorch 2nd order derivative test 
f = lambda x: x**3 + 2*x**2 - 3*x + 1
x = torch.tensor(1.0, requires_grad=True)

z = f(x)
y = z


dydx = torch.autograd.grad(y, x, create_graph=True)
d2ydx = torch.autograd.grad(dydx, x) # 10
print(dydx, d2ydx)
# Out:
# (tensor(4., grad_fn=<AddBackward0>),) (tensor(10.),)

# %%
inputs
# Out:
# tensor([[[[-0.3043, -0.4303, -0.3762,  ...,  0.5134,  1.7095,  2.8476],
#           [-0.1027,  0.5423,  0.4987,  ...,  0.6480,  0.7588,  1.8047],
#           [ 2.0492,  1.8057,  0.5868,  ..., -0.2155, -0.4123,  0.1292],
#           ...,
#           [-0.5023, -0.5069, -0.5051,  ..., -0.5088, -0.5086, -0.5027],
#           [-0.4878, -0.4942, -0.5019,  ..., -0.5002, -0.5069, -0.5045],
#           [-0.4990, -0.5016, -0.4991,  ..., -0.5022, -0.5019, -0.4977]]]],
#        device='cuda:0')

# %%
x_hat
# Out:
# Parameter containing:
# tensor([[[[-0.1900, -0.2737, -0.2501,  ..., -0.2592, -0.2041,  0.0140],
#           [-0.0889, -0.2980, -0.2423,  ..., -0.0524, -0.1539,  0.0339],
#           [-0.0138, -0.0941, -0.2136,  ...,  0.2180,  0.0822,  0.1171],
#           ...,
#           [-0.0406,  0.0202,  0.0043,  ..., -0.1420, -0.1500, -0.1585],
#           [ 0.0349, -0.0315, -0.0175,  ..., -0.1832, -0.0994, -0.1352],
#           [-0.0318, -0.0050, -0.0319,  ..., -0.1332, -0.0814, -0.0823]]]],
#        device='cuda:0', requires_grad=True)
