# %%
# %load_ext autoreload
# %autoreload 2

import os,sys
sys.path.insert(0, os.path.abspath('../..')) # root 
sys.path.insert(1, os.path.abspath('../../modules/deepspeech_pytorch') ) #modules deepspeech 
import torch
import torch.nn as nn
import hydra
from src.autodiff.ctc_loss_imp import ctc_loss_imp

from deepspeech_pytorch.model import DeepSpeech, SequenceWise
from src.utils.plot_utils import *

import matplotlib
# %matplotlib inline

# %%
def get_deep_speech_model_saved_20_10(device) -> DeepSpeech:


    from hydra.core.config_store import ConfigStore
    from deepspeech_pytorch.configs.inference_config import EvalConfig
    
    cs = ConfigStore.instance()
    cs.store(name="config", node=EvalConfig)
    cfg = EvalConfig()
    # model_path='/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/librispeech_pretrained_v3.ckpt'
    model_path='/scratch/f006pq6/projects/gitrepos/deepspeech.pytorch/outputs/2023-11-01/23-31-50/lightning_logs/version_0/checkpoints/epoch=5-step=19295.ckpt'
    model_ds = DeepSpeech.load_from_checkpoint(model_path)
    model_ds.train()
    model_ds = model_ds.to(device)

    # modify window size and window stride of spect_cfg
    model_ds.spect_cfg.window_size = 0.032 # 32 ms
    model_ds.spect_cfg.window_stride = 0.020 # 20 ms

    return model_ds

def get_deep_speech_model_32_20(device) -> DeepSpeech:
    import json
    label_file = '../../modules/deepspeech_pytorch/labels.json'
    with open(label_file) as label_file:
        labels = json.load(label_file)

    from deepspeech_pytorch.configs.train_config import DeepSpeechConfig
    from deepspeech_pytorch.configs.train_config import UniDirectionalConfig

    cfg = DeepSpeechConfig()
    model_ds = DeepSpeech(
        labels=labels,
        model_cfg=UniDirectionalConfig(),
        optim_cfg=cfg.optim,
        precision=cfg.trainer.precision,
        spect_cfg=cfg.data.spect
    )

    model_ds.train()
    model_ds = model_ds.to(device)

    # modify window size and window stride of spect_cfg
    # model_ds.spect_cfg.window_size = 0.032 # 32 ms
    # model_ds.spect_cfg.window_stride = 0.020 # 20 ms

    return model_ds


def get_dataloader(model_ds: DeepSpeech, batch_size=1, num_workers=4):
    from deepspeech_pytorch.loader.data_loader import SpectrogramDataset, AudioDataLoader
    
    test_dir = '/scratch/f006pq6/datasets/librispeech/test_clean'
    test_dataset = SpectrogramDataset(
        audio_conf=model_ds.spect_cfg,
        input_path=hydra.utils.to_absolute_path(test_dir),
        labels=model_ds.labels,
        normalize=True
    )
    test_loader = AudioDataLoader(
        test_dataset,
        batch_size=batch_size,
        num_workers=num_workers
    )
    return test_loader

device ='cuda:0'
model_ds = get_deep_speech_model_32_20(device)
test_loader = get_dataloader(model_ds, batch_size=1, num_workers=4)
test_loader_iter = iter(test_loader)

# %%
test_loader.dataset[0][0].shape

# %%
def length_filter(dataset, sr=16000, window_size_ms=32, window_step_ms=20):
    """
    Print out samples from the dataset with lengths ranging from 1 second to 3 seconds.
    
    Args:
    - dataset: PyTorch dataset returning T x F tensors.
    - sr: Sampling rate.
    - window_size_ms: Window size in milliseconds.
    - window_step_ms: Window step in milliseconds.
    """
    # Calculate window size and step in samples
    window_size_samples = int(sr * (window_size_ms / 1000))
    window_step_samples = int(sr * (window_step_ms / 1000))
    
    # Iterate over samples in the dataset

    good_indices =[]
    for i in range(len(dataset)):
        dur = dataset[i][0].shape[1] * window_step_samples / sr
        # print(dur)
        if dur >= 1 and dur <= 3.5:
            print(f"Sample {i}: Length = {dur:.2f} seconds")
            # print(dataset[i][-1])
            good_indices.append(i)
    return good_indices

# %%
test_loader.dataset[4][0].shape
# Out:
# torch.Size([257, 554])

# %%
good_idx = length_filter(test_loader.dataset)
# Out:
# Sample 1: Length = 3.32 seconds
# Sample 6: Length = 3.20 seconds
# Sample 9: Length = 3.04 seconds
# Sample 15: Length = 2.96 seconds
# Sample 20: Length = 1.96 seconds
# Sample 22: Length = 3.10 seconds
# Sample 24: Length = 3.40 seconds
# Sample 26: Length = 2.84 seconds
# Sample 33: Length = 3.22 seconds
# Sample 36: Length = 1.90 seconds
# Sample 38: Length = 3.04 seconds
# Sample 40: Length = 2.58 seconds
# Sample 42: Length = 3.42 seconds
# Sample 45: Length = 2.16 seconds
# Sample 46: Length = 2.70 seconds
# Sample 51: Length = 3.24 seconds
# Sample 53: Length = 1.82 seconds
# Sample 54: Length = 3.32 seconds
# Sample 60: Length = 3.30 seconds
# Sample 62: Length = 2.18 seconds
# Sample 63: Length = 3.40 seconds
# Sample 71: Length = 3.08 seconds
# Sample 72: Length = 2.94 seconds
# Sample 74: Length = 2.54 seconds
# Sample 75: Length = 2.36 seconds
# Sample 118: Length = 2.26 seconds
# Sample 126: Length = 3.50 seconds
# Sample 143: Length = 2.68 seconds
# Sample 147: Length = 2.38 seconds
# Sample 168: Length = 2.22 seconds
# Sample 181: Length = 1.76 seconds
# Sample 183: Length = 3.40 seconds
# Sample 184: Length = 2.72 seconds
# Sample 187: Length = 3.12 seconds
# Sample 191: Length = 2.18 seconds
# Sample 192: Length = 3.08 seconds
# Sample 193: Length = 3.12 seconds
# Sample 198: Length = 3.48 seconds
# Sample 203: Length = 3.00 seconds
# Sample 204: Length = 3.08 seconds
# Sample 211: Length = 3.08 seconds
# Sample 212: Length = 2.58 seconds
# Sample 217: Length = 2.44 seconds
# Sample 220: Length = 2.56 seconds
# Sample 223: Length = 3.06 seconds
# Sample 229: Length = 3.24 seconds
# Sample 230: Length = 3.48 seconds
# Sample 232: Length = 3.26 seconds
# Sample 233: Length = 2.72 seconds
# Sample 243: Length = 2.40 seconds
# Sample 244: Length = 2.96 seconds
# Sample 245: Length = 1.82 seconds
# Sample 246: Length = 2.92 seconds
# Sample 253: Length = 2.62 seconds
# Sample 254: Length = 3.06 seconds
# Sample 260: Length = 3.44 seconds
# Sample 269: Length = 3.30 seconds
# Sample 274: Length = 2.68 seconds
# Sample 275: Length = 3.46 seconds
# Sample 285: Length = 2.72 seconds
# Sample 309: Length = 3.02 seconds
# Sample 310: Length = 3.40 seconds
# Sample 311: Length = 2.66 seconds
# Sample 313: Length = 1.92 seconds
# Sample 314: Length = 2.80 seconds
# Sample 319: Length = 2.68 seconds
# Sample 320: Length = 2.44 seconds
# Sample 323: Length = 2.28 seconds
# Sample 326: Length = 2.46 seconds
# Sample 327: Length = 2.30 seconds
# Sample 330: Length = 3.26 seconds
# Sample 331: Length = 2.22 seconds
# Sample 335: Length = 2.72 seconds
# Sample 342: Length = 2.72 seconds
# Sample 345: Length = 3.16 seconds
# Sample 361: Length = 1.44 seconds
# Sample 364: Length = 2.84 seconds
# Sample 365: Length = 2.66 seconds
# Sample 366: Length = 2.40 seconds
# Sample 368: Length = 2.84 seconds
# Sample 369: Length = 1.70 seconds
# Sample 375: Length = 3.00 seconds
# Sample 386: Length = 2.72 seconds
# Sample 389: Length = 3.50 seconds
# Sample 390: Length = 3.02 seconds
# Sample 401: Length = 3.38 seconds
# Sample 402: Length = 3.04 seconds
# Sample 408: Length = 2.94 seconds
# Sample 415: Length = 3.12 seconds
# Sample 418: Length = 2.12 seconds
# Sample 427: Length = 1.92 seconds
# Sample 431: Length = 2.68 seconds
# Sample 432: Length = 2.46 seconds
# Sample 441: Length = 2.18 seconds
# Sample 442: Length = 1.94 seconds
# Sample 443: Length = 3.24 seconds
# Sample 446: Length = 2.78 seconds
# Sample 447: Length = 3.32 seconds
# Sample 452: Length = 2.16 seconds
# Sample 460: Length = 2.98 seconds
# Sample 463: Length = 1.70 seconds
# Sample 467: Length = 2.64 seconds
# Sample 471: Length = 3.36 seconds
# Sample 488: Length = 2.68 seconds
# Sample 490: Length = 3.18 seconds
# Sample 491: Length = 2.18 seconds
# Sample 541: Length = 2.96 seconds
# Sample 546: Length = 3.14 seconds
# Sample 547: Length = 2.24 seconds
# Sample 549: Length = 2.44 seconds
# Sample 550: Length = 2.84 seconds
# Sample 551: Length = 3.32 seconds
# Sample 554: Length = 2.18 seconds
# Sample 555: Length = 3.36 seconds
# Sample 559: Length = 2.42 seconds
# Sample 562: Length = 3.16 seconds
# Sample 563: Length = 3.28 seconds
# Sample 565: Length = 2.88 seconds
# Sample 568: Length = 3.40 seconds
# Sample 569: Length = 2.58 seconds
# Sample 574: Length = 3.42 seconds
# Sample 577: Length = 3.00 seconds
# Sample 579: Length = 2.24 seconds
# Sample 580: Length = 2.90 seconds
# Sample 582: Length = 2.34 seconds
# Sample 583: Length = 2.14 seconds
# Sample 608: Length = 3.30 seconds
# Sample 609: Length = 3.44 seconds
# Sample 615: Length = 2.32 seconds
# Sample 624: Length = 3.10 seconds
# Sample 635: Length = 3.34 seconds
# Sample 642: Length = 3.04 seconds
# Sample 650: Length = 3.40 seconds
# Sample 655: Length = 2.42 seconds
# Sample 656: Length = 2.94 seconds
# Sample 660: Length = 2.36 seconds
# Sample 662: Length = 2.70 seconds
# Sample 668: Length = 2.18 seconds
# Sample 669: Length = 3.26 seconds
# Sample 671: Length = 2.46 seconds
# Sample 673: Length = 2.00 seconds
# Sample 676: Length = 3.30 seconds
# Sample 685: Length = 2.96 seconds
# Sample 689: Length = 2.36 seconds
# Sample 693: Length = 2.36 seconds
# Sample 694: Length = 2.66 seconds
# Sample 696: Length = 2.70 seconds
# Sample 700: Length = 2.74 seconds
# Sample 703: Length = 1.98 seconds
# Sample 705: Length = 2.76 seconds
# Sample 709: Length = 3.24 seconds
# Sample 729: Length = 3.20 seconds
# Sample 756: Length = 3.04 seconds
# Sample 767: Length = 2.52 seconds
# Sample 769: Length = 3.30 seconds
# Sample 770: Length = 2.46 seconds
# Sample 772: Length = 2.46 seconds
# Sample 774: Length = 2.90 seconds
# Sample 777: Length = 3.38 seconds
# Sample 792: Length = 2.52 seconds
# Sample 795: Length = 2.62 seconds
# Sample 797: Length = 2.40 seconds
# Sample 813: Length = 2.48 seconds
# Sample 814: Length = 2.14 seconds
# Sample 815: Length = 2.62 seconds
# Sample 822: Length = 3.50 seconds
# Sample 824: Length = 2.68 seconds
# Sample 826: Length = 3.34 seconds
# Sample 827: Length = 3.10 seconds
# Sample 829: Length = 2.76 seconds
# Sample 832: Length = 2.72 seconds
# Sample 837: Length = 2.84 seconds
# Sample 843: Length = 2.76 seconds
# Sample 844: Length = 2.80 seconds
# Sample 846: Length = 3.30 seconds
# Sample 848: Length = 2.00 seconds
# Sample 853: Length = 3.46 seconds
# Sample 855: Length = 2.30 seconds
# Sample 864: Length = 2.86 seconds
# Sample 865: Length = 2.60 seconds
# Sample 870: Length = 2.80 seconds
# Sample 871: Length = 2.98 seconds
# Sample 873: Length = 2.02 seconds
# Sample 874: Length = 3.14 seconds
# Sample 878: Length = 3.38 seconds
# Sample 879: Length = 2.88 seconds
# Sample 882: Length = 3.12 seconds
# Sample 883: Length = 3.20 seconds
# Sample 887: Length = 3.24 seconds
# Sample 894: Length = 1.92 seconds
# Sample 895: Length = 2.94 seconds
# Sample 945: Length = 2.40 seconds
# Sample 954: Length = 2.68 seconds
# Sample 960: Length = 2.54 seconds
# Sample 961: Length = 2.74 seconds
# Sample 964: Length = 2.06 seconds
# Sample 966: Length = 3.08 seconds
# Sample 970: Length = 3.30 seconds
# Sample 971: Length = 3.08 seconds
# Sample 974: Length = 2.52 seconds
# Sample 977: Length = 3.16 seconds
# Sample 981: Length = 2.60 seconds
# Sample 982: Length = 2.92 seconds
# Sample 983: Length = 2.68 seconds
# Sample 986: Length = 3.24 seconds
# Sample 992: Length = 2.14 seconds
# Sample 994: Length = 2.18 seconds
# Sample 995: Length = 2.58 seconds
# Sample 996: Length = 2.34 seconds
# Sample 1004: Length = 2.76 seconds
# Sample 1009: Length = 3.50 seconds
# Sample 1011: Length = 2.96 seconds
# Sample 1012: Length = 2.86 seconds
# Sample 1019: Length = 3.10 seconds
# Sample 1026: Length = 3.36 seconds
# Sample 1038: Length = 2.88 seconds
# Sample 1043: Length = 2.62 seconds
# Sample 1050: Length = 3.02 seconds
# Sample 1052: Length = 2.10 seconds
# Sample 1055: Length = 2.22 seconds
# Sample 1056: Length = 3.46 seconds
# Sample 1061: Length = 2.18 seconds
# Sample 1067: Length = 3.40 seconds
# Sample 1069: Length = 3.10 seconds
# Sample 1073: Length = 3.16 seconds
# Sample 1075: Length = 3.20 seconds
# Sample 1077: Length = 2.72 seconds
# Sample 1078: Length = 3.28 seconds
# Sample 1095: Length = 3.34 seconds
# Sample 1096: Length = 2.24 seconds
# Sample 1099: Length = 3.46 seconds
# Sample 1108: Length = 2.70 seconds
# Sample 1112: Length = 3.26 seconds
# Sample 1113: Length = 2.72 seconds
# Sample 1126: Length = 2.42 seconds
# Sample 1127: Length = 2.68 seconds
# Sample 1130: Length = 3.04 seconds
# Sample 1134: Length = 2.64 seconds
# Sample 1139: Length = 3.12 seconds
# Sample 1142: Length = 3.32 seconds
# Sample 1143: Length = 2.64 seconds
# Sample 1145: Length = 3.30 seconds
# Sample 1148: Length = 3.42 seconds
# Sample 1150: Length = 2.40 seconds
# Sample 1151: Length = 2.80 seconds
# Sample 1154: Length = 3.32 seconds
# Sample 1155: Length = 1.80 seconds
# Sample 1159: Length = 3.10 seconds
# Sample 1160: Length = 3.00 seconds
# Sample 1162: Length = 2.76 seconds
# Sample 1163: Length = 3.14 seconds
# Sample 1164: Length = 3.06 seconds
# Sample 1167: Length = 2.10 seconds
# Sample 1168: Length = 2.92 seconds
# Sample 1170: Length = 2.40 seconds
# Sample 1171: Length = 1.92 seconds
# Sample 1173: Length = 2.12 seconds
# Sample 1176: Length = 2.18 seconds
# Sample 1177: Length = 3.00 seconds
# Sample 1178: Length = 2.52 seconds
# Sample 1182: Length = 2.74 seconds
# Sample 1184: Length = 2.10 seconds
# Sample 1188: Length = 2.68 seconds
# Sample 1190: Length = 3.30 seconds
# Sample 1191: Length = 3.10 seconds
# Sample 1194: Length = 2.64 seconds
# Sample 1195: Length = 3.00 seconds
# Sample 1198: Length = 2.32 seconds
# Sample 1199: Length = 2.08 seconds
# Sample 1203: Length = 2.44 seconds
# Sample 1205: Length = 2.48 seconds
# Sample 1207: Length = 2.62 seconds
# Sample 1208: Length = 3.26 seconds
# Sample 1241: Length = 2.94 seconds
# Sample 1261: Length = 2.36 seconds
# Sample 1266: Length = 3.28 seconds
# Sample 1268: Length = 2.28 seconds
# Sample 1272: Length = 3.44 seconds
# Sample 1274: Length = 3.50 seconds
# Sample 1278: Length = 3.44 seconds
# Sample 1279: Length = 2.70 seconds
# Sample 1286: Length = 2.90 seconds
# Sample 1288: Length = 2.92 seconds
# Sample 1291: Length = 2.68 seconds
# Sample 1292: Length = 1.98 seconds
# Sample 1293: Length = 2.64 seconds
# Sample 1294: Length = 2.50 seconds
# Sample 1297: Length = 3.04 seconds
# Sample 1308: Length = 2.38 seconds
# Sample 1309: Length = 2.70 seconds
# Sample 1310: Length = 1.84 seconds
# Sample 1316: Length = 2.98 seconds
# Sample 1321: Length = 3.34 seconds
# Sample 1323: Length = 2.04 seconds
# Sample 1325: Length = 3.44 seconds
# Sample 1326: Length = 1.50 seconds
# Sample 1329: Length = 3.48 seconds
# Sample 1331: Length = 2.72 seconds
# Sample 1332: Length = 2.54 seconds
# Sample 1343: Length = 1.96 seconds
# Sample 1346: Length = 2.12 seconds
# Sample 1348: Length = 3.38 seconds
# Sample 1351: Length = 3.18 seconds
# Sample 1352: Length = 2.12 seconds
# Sample 1357: Length = 3.40 seconds
# Sample 1358: Length = 2.28 seconds
# Sample 1359: Length = 2.60 seconds
# Sample 1360: Length = 3.50 seconds
# Sample 1362: Length = 3.14 seconds
# Sample 1371: Length = 2.92 seconds
# Sample 1374: Length = 2.34 seconds
# Sample 1375: Length = 2.40 seconds
# Sample 1376: Length = 2.76 seconds
# Sample 1377: Length = 2.96 seconds
# Sample 1381: Length = 2.90 seconds
# Sample 1383: Length = 1.96 seconds
# Sample 1385: Length = 1.96 seconds
# Sample 1387: Length = 3.22 seconds
# Sample 1388: Length = 2.80 seconds
# Sample 1391: Length = 3.10 seconds
# Sample 1393: Length = 3.32 seconds
# Sample 1395: Length = 3.32 seconds
# Sample 1396: Length = 3.08 seconds
# Sample 1398: Length = 3.48 seconds
# Sample 1400: Length = 2.22 seconds
# Sample 1401: Length = 2.78 seconds
# Sample 1402: Length = 2.02 seconds
# Sample 1403: Length = 3.32 seconds
# Sample 1404: Length = 2.12 seconds
# Sample 1407: Length = 2.52 seconds
# Sample 1408: Length = 2.22 seconds
# Sample 1410: Length = 2.78 seconds
# Sample 1419: Length = 2.84 seconds
# Sample 1421: Length = 2.40 seconds
# Sample 1424: Length = 3.46 seconds
# Sample 1425: Length = 3.38 seconds
# Sample 1426: Length = 2.62 seconds
# Sample 1427: Length = 3.50 seconds
# Sample 1428: Length = 2.12 seconds
# Sample 1431: Length = 2.34 seconds
# Sample 1433: Length = 2.22 seconds
# Sample 1437: Length = 3.44 seconds
# Sample 1439: Length = 2.54 seconds
# Sample 1459: Length = 3.06 seconds
# Sample 1465: Length = 3.10 seconds
# Sample 1470: Length = 3.16 seconds
# Sample 1472: Length = 2.56 seconds
# Sample 1474: Length = 2.72 seconds
# Sample 1477: Length = 2.68 seconds
# Sample 1478: Length = 2.60 seconds
# Sample 1482: Length = 3.12 seconds
# Sample 1488: Length = 2.28 seconds
# Sample 1494: Length = 3.16 seconds
# Sample 1497: Length = 2.16 seconds
# Sample 1499: Length = 2.78 seconds
# Sample 1504: Length = 3.02 seconds
# Sample 1506: Length = 2.86 seconds
# Sample 1513: Length = 3.42 seconds
# Sample 1515: Length = 3.22 seconds
# Sample 1526: Length = 2.72 seconds
# Sample 1536: Length = 3.18 seconds
# Sample 1537: Length = 3.28 seconds
# Sample 1538: Length = 2.14 seconds
# Sample 1546: Length = 2.90 seconds
# Sample 1580: Length = 2.72 seconds
# Sample 1581: Length = 2.78 seconds
# Sample 1583: Length = 2.42 seconds
# Sample 1596: Length = 2.18 seconds
# Sample 1601: Length = 3.40 seconds
# Sample 1604: Length = 2.54 seconds
# Sample 1608: Length = 2.24 seconds
# Sample 1609: Length = 2.92 seconds
# Sample 1612: Length = 3.26 seconds
# Sample 1617: Length = 2.24 seconds
# Sample 1621: Length = 2.16 seconds
# Sample 1622: Length = 3.34 seconds
# Sample 1623: Length = 2.54 seconds
# Sample 1624: Length = 2.14 seconds
# Sample 1626: Length = 3.08 seconds
# Sample 1627: Length = 2.64 seconds
# Sample 1629: Length = 2.00 seconds
# Sample 1630: Length = 3.08 seconds
# Sample 1632: Length = 3.24 seconds
# Sample 1633: Length = 2.18 seconds
# Sample 1634: Length = 2.82 seconds
# Sample 1636: Length = 2.90 seconds
# Sample 1642: Length = 2.62 seconds
# Sample 1644: Length = 3.34 seconds
# Sample 1655: Length = 2.78 seconds
# Sample 1658: Length = 3.28 seconds
# Sample 1659: Length = 2.92 seconds
# Sample 1667: Length = 1.98 seconds
# Sample 1670: Length = 2.04 seconds
# Sample 1671: Length = 2.68 seconds
# Sample 1673: Length = 2.56 seconds
# Sample 1675: Length = 1.30 seconds
# Sample 1676: Length = 3.06 seconds
# Sample 1677: Length = 2.32 seconds
# Sample 1678: Length = 1.90 seconds
# Sample 1691: Length = 3.00 seconds
# Sample 1701: Length = 2.98 seconds
# Sample 1704: Length = 2.94 seconds
# Sample 1710: Length = 3.08 seconds
# Sample 1720: Length = 2.32 seconds
# Sample 1721: Length = 2.90 seconds
# Sample 1734: Length = 3.02 seconds
# Sample 1735: Length = 2.76 seconds
# Sample 1736: Length = 2.98 seconds
# Sample 1739: Length = 3.32 seconds
# Sample 1755: Length = 3.32 seconds
# Sample 1757: Length = 2.86 seconds
# Sample 1793: Length = 3.12 seconds
# Sample 1795: Length = 2.98 seconds
# Sample 1814: Length = 2.94 seconds
# Sample 1815: Length = 2.00 seconds
# Sample 1821: Length = 2.64 seconds
# Sample 1823: Length = 2.12 seconds
# Sample 1827: Length = 3.28 seconds
# Sample 1830: Length = 3.38 seconds
# Sample 1832: Length = 2.20 seconds
# Sample 1836: Length = 2.14 seconds
# Sample 1844: Length = 3.20 seconds
# Sample 1846: Length = 2.60 seconds
# Sample 1847: Length = 2.74 seconds
# Sample 1859: Length = 2.56 seconds
# Sample 1868: Length = 2.96 seconds
# Sample 1869: Length = 3.36 seconds
# Sample 1878: Length = 3.04 seconds
# Sample 1890: Length = 2.64 seconds
# Sample 1901: Length = 2.90 seconds
# Sample 1904: Length = 3.10 seconds
# Sample 1911: Length = 2.76 seconds
# Sample 1917: Length = 3.46 seconds
# Sample 1930: Length = 2.14 seconds
# Sample 1932: Length = 2.34 seconds
# Sample 1935: Length = 2.52 seconds
# Sample 1955: Length = 2.50 seconds
# Sample 1957: Length = 2.12 seconds
# Sample 1960: Length = 3.28 seconds
# Sample 1974: Length = 2.46 seconds
# Sample 1980: Length = 2.70 seconds
# Sample 1981: Length = 3.04 seconds
# Sample 1983: Length = 2.82 seconds
# Sample 1988: Length = 2.76 seconds
# Sample 1991: Length = 2.78 seconds
# Sample 1992: Length = 2.16 seconds
# Sample 2002: Length = 3.26 seconds
# Sample 2003: Length = 2.30 seconds
# Sample 2007: Length = 2.18 seconds
# Sample 2015: Length = 3.28 seconds
# Sample 2016: Length = 2.24 seconds
# Sample 2017: Length = 2.08 seconds
# Sample 2018: Length = 2.96 seconds
# Sample 2020: Length = 2.04 seconds
# Sample 2021: Length = 2.08 seconds
# Sample 2024: Length = 3.36 seconds
# Sample 2030: Length = 2.90 seconds
# Sample 2031: Length = 2.16 seconds
# Sample 2034: Length = 2.14 seconds
# Sample 2036: Length = 2.66 seconds
# Sample 2038: Length = 2.38 seconds
# Sample 2039: Length = 3.48 seconds
# Sample 2040: Length = 2.48 seconds
# Sample 2041: Length = 2.50 seconds
# Sample 2042: Length = 2.64 seconds
# Sample 2048: Length = 2.52 seconds
# Sample 2049: Length = 2.36 seconds
# Sample 2058: Length = 3.28 seconds
# Sample 2060: Length = 2.00 seconds
# Sample 2062: Length = 2.38 seconds
# Sample 2063: Length = 2.66 seconds
# Sample 2069: Length = 2.88 seconds
# Sample 2070: Length = 2.74 seconds
# Sample 2072: Length = 3.06 seconds
# Sample 2084: Length = 3.36 seconds
# Sample 2096: Length = 2.44 seconds
# Sample 2099: Length = 2.88 seconds
# Sample 2101: Length = 2.24 seconds
# Sample 2106: Length = 3.34 seconds
# Sample 2110: Length = 3.04 seconds
# Sample 2122: Length = 2.84 seconds
# Sample 2126: Length = 3.32 seconds
# Sample 2134: Length = 2.72 seconds
# Sample 2144: Length = 3.14 seconds
# Sample 2150: Length = 2.98 seconds
# Sample 2160: Length = 2.72 seconds
# Sample 2178: Length = 2.16 seconds
# Sample 2183: Length = 2.94 seconds
# Sample 2184: Length = 2.98 seconds
# Sample 2187: Length = 1.84 seconds
# Sample 2192: Length = 2.56 seconds
# Sample 2197: Length = 3.14 seconds
# Sample 2199: Length = 2.78 seconds
# Sample 2200: Length = 2.70 seconds
# Sample 2203: Length = 2.42 seconds
# Sample 2204: Length = 3.04 seconds
# Sample 2212: Length = 3.50 seconds
# Sample 2215: Length = 2.94 seconds
# Sample 2220: Length = 2.94 seconds
# Sample 2222: Length = 2.18 seconds
# Sample 2227: Length = 2.62 seconds
# Sample 2232: Length = 2.66 seconds
# Sample 2235: Length = 2.80 seconds
# Sample 2237: Length = 3.48 seconds
# Sample 2241: Length = 2.06 seconds
# Sample 2248: Length = 2.56 seconds
# Sample 2252: Length = 3.42 seconds
# Sample 2253: Length = 3.14 seconds
# Sample 2259: Length = 3.14 seconds
# Sample 2260: Length = 3.42 seconds
# Sample 2264: Length = 2.34 seconds
# Sample 2265: Length = 3.44 seconds
# Sample 2266: Length = 2.04 seconds
# Sample 2273: Length = 3.06 seconds
# Sample 2274: Length = 3.26 seconds
# Sample 2276: Length = 2.16 seconds
# Sample 2286: Length = 1.82 seconds
# Sample 2290: Length = 2.86 seconds
# Sample 2293: Length = 3.10 seconds
# Sample 2295: Length = 3.26 seconds
# Sample 2296: Length = 2.44 seconds
# Sample 2299: Length = 1.96 seconds
# Sample 2302: Length = 2.12 seconds
# Sample 2309: Length = 2.28 seconds
# Sample 2315: Length = 3.28 seconds
# Sample 2324: Length = 2.52 seconds
# Sample 2329: Length = 2.16 seconds
# Sample 2333: Length = 2.56 seconds
# Sample 2344: Length = 3.28 seconds
# Sample 2346: Length = 3.18 seconds
# Sample 2347: Length = 3.28 seconds
# Sample 2348: Length = 2.20 seconds
# Sample 2349: Length = 2.08 seconds
# Sample 2351: Length = 2.88 seconds
# Sample 2352: Length = 2.44 seconds
# Sample 2355: Length = 2.80 seconds
# Sample 2356: Length = 2.24 seconds
# Sample 2359: Length = 3.06 seconds
# Sample 2364: Length = 2.24 seconds
# Sample 2365: Length = 3.08 seconds
# Sample 2368: Length = 3.08 seconds
# Sample 2370: Length = 3.36 seconds
# Sample 2372: Length = 2.20 seconds
# Sample 2373: Length = 2.40 seconds
# Sample 2374: Length = 2.58 seconds
# Sample 2380: Length = 2.56 seconds
# Sample 2381: Length = 2.40 seconds
# Sample 2382: Length = 1.64 seconds
# Sample 2383: Length = 3.18 seconds
# Sample 2387: Length = 1.82 seconds
# Sample 2389: Length = 2.32 seconds
# Sample 2392: Length = 2.98 seconds
# Sample 2397: Length = 2.88 seconds
# Sample 2404: Length = 2.04 seconds
# Sample 2407: Length = 2.26 seconds
# Sample 2430: Length = 3.30 seconds
# Sample 2437: Length = 3.22 seconds
# Sample 2483: Length = 2.80 seconds
# Sample 2485: Length = 2.60 seconds
# Sample 2489: Length = 3.36 seconds
# Sample 2490: Length = 3.08 seconds
# Sample 2497: Length = 2.20 seconds
# Sample 2498: Length = 2.62 seconds
# Sample 2511: Length = 2.02 seconds
# Sample 2514: Length = 2.96 seconds
# Sample 2519: Length = 2.38 seconds
# Sample 2524: Length = 1.92 seconds
# Sample 2529: Length = 2.88 seconds
# Sample 2533: Length = 2.76 seconds
# Sample 2536: Length = 2.28 seconds
# Sample 2539: Length = 3.48 seconds
# Sample 2542: Length = 3.32 seconds
# Sample 2543: Length = 3.48 seconds
# Sample 2551: Length = 3.20 seconds
# Sample 2553: Length = 2.84 seconds
# Sample 2554: Length = 2.66 seconds
# Sample 2555: Length = 2.36 seconds
# Sample 2565: Length = 2.50 seconds
# Sample 2570: Length = 3.18 seconds
# Sample 2572: Length = 3.12 seconds
# Sample 2581: Length = 2.78 seconds
# Sample 2583: Length = 2.26 seconds
# Sample 2585: Length = 2.36 seconds
# Sample 2587: Length = 2.18 seconds
# Sample 2589: Length = 2.70 seconds
# Sample 2595: Length = 2.02 seconds
# Sample 2596: Length = 2.12 seconds
# Sample 2598: Length = 2.78 seconds
# Sample 2600: Length = 2.04 seconds
# Sample 2601: Length = 2.30 seconds
# Sample 2602: Length = 2.98 seconds
# Sample 2608: Length = 2.86 seconds
# Sample 2609: Length = 3.18 seconds
# Sample 2618: Length = 1.88 seconds

# %%
len(good_idx)
# Out:
# 594
